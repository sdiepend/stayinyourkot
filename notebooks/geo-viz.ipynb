# %%
import plotly.express as px
import pandas as pd
import json
import requests

# %%
resp = requests.get("https://raw.githubusercontent.com/Datafable/rolling-blackout-belgium/master/data/geospatial/municipalities-belgium.geojson")
municipalities = resp.json()
municipalities
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[4.284636, 50.845249],
#        [4.283894, 50.840671],
#        [4.282112, 50.839588],
#        [4.283052, 50.837979],
#        [4.27318, 50.838742],
#        [4.271828, 50.836262],
#        [4.256418, 50.834908],
#        [4.254548, 50.833454],
#        [4.255798, 50.829731],
#        [4.253017, 50.825131],
#        [4.244673, 50.819466],
#        [4.245567, 50.817627],
#        [4.247497, 50.817345],
#        [4.247203, 50.819023],
#        [4.250306, 50.81942],
#        [4.251937, 50.8172],
#        [4.256503, 50.817295],
#        [4.259908, 50.811089],
#        [4.272742, 50.812222],
#        [4.275658, 50.810955],
#        [4.276961, 50.80838],
#        [4.283621, 50.807079],
#        [4.294198, 50.808224],
#        [4.297497, 50.809529],
#        [4.300175, 50.812828],
#        [4.306363, 50.812462],
#        [4.31035, 50.813526],
# ...
